# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunKhatter/machine-learning-/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request

urllib.request.urlretrieve('https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv','arjun.csv')
# Out:
# ('arjun.csv', <http.client.HTTPMessage at 0x7bd89873ad70>)

# %% [markdown]
# install pandas

# %%
pip install pandas

# %% [markdown]
# import pandas

# %%
import pandas as pd

# %% [markdown]
# getting and reading the file

# %%
covid_df=pd.read_csv('arjun.csv')

# %% [markdown]
# serching thr information about it

# %%
covid_df.info
# Out:
# <bound method DataFrame.info of            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]>

# %% [markdown]
# for printing all the sheet

# %%
covid_df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %% [markdown]
# to print all the columns

# %%
covid_df.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests'], dtype='object')

# %% [markdown]
# to print the shape

# %%
covid_df.shape
# Out:
# (248, 4)

# %% [markdown]
# prints all the dates

# %%
covid_df['date']
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %% [markdown]
# to print first 20 values

# %%
covid_df.head(20)
# Out:
#           date  new_cases  new_deaths  new_tests
# 0   2019-12-31        0.0         0.0        NaN
# 1   2020-01-01        0.0         0.0        NaN
# 2   2020-01-02        0.0         0.0        NaN
# 3   2020-01-03        0.0         0.0        NaN
# 4   2020-01-04        0.0         0.0        NaN
# 5   2020-01-05        0.0         0.0        NaN
# 6   2020-01-06        0.0         0.0        NaN
# 7   2020-01-07        0.0         0.0        NaN
# 8   2020-01-08        0.0         0.0        NaN
# 9   2020-01-09        0.0         0.0        NaN
# 10  2020-01-10        0.0         0.0        NaN
# 11  2020-01-11        0.0         0.0        NaN
# 12  2020-01-12        0.0         0.0        NaN
# 13  2020-01-13        0.0         0.0        NaN
# 14  2020-01-14        0.0         0.0        NaN
# 15  2020-01-15        0.0         0.0        NaN
# 16  2020-01-16        0.0         0.0        NaN
# 17  2020-01-17        0.0         0.0        NaN
# ...

# %% [markdown]
# to print last 20 values

# %%
covid_df.tail(20)
# Out:
#            date  new_cases  new_deaths  new_tests
# 228  2020-08-15      574.0         3.0    25937.0
# 229  2020-08-16      629.0       158.0    22470.0
# 230  2020-08-17      477.0         4.0    21379.0
# 231  2020-08-18      320.0         4.0    32687.0
# 232  2020-08-19      401.0         5.0    41290.0
# 233  2020-08-20      642.0         7.0    49662.0
# 234  2020-08-21      840.0         6.0    44943.0
# 235  2020-08-22      947.0         9.0    46613.0
# 236  2020-08-23     1071.0         3.0    47463.0
# 237  2020-08-24     1209.0         7.0    33358.0
# 238  2020-08-25      953.0         4.0    45798.0
# 239  2020-08-26      876.0         4.0    58054.0
# 240  2020-08-27     1366.0        13.0    57640.0
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# ...

# %% [markdown]
# to print date of a specific value

# %%
covid_df['date'][246]
# Out:
# '2020-09-02'

# %% [markdown]
# to print only 2 columns

# %%
covid_df[['date','new_cases']]
# Out:
#            date  new_cases
# 0    2019-12-31        0.0
# 1    2020-01-01        0.0
# 2    2020-01-02        0.0
# 3    2020-01-03        0.0
# 4    2020-01-04        0.0
# ..          ...        ...
# 243  2020-08-30     1444.0
# 244  2020-08-31     1365.0
# 245  2020-09-01      996.0
# 246  2020-09-02      975.0
# 247  2020-09-03     1326.0
#
# [248 rows x 2 columns]

# %% [markdown]
# copying the sheet

# %%
covid_df.copy()
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %% [markdown]
# print all the columns of a specific cell

# %%
covid_df.loc[246]
# Out:
# date          2020-09-02
# new_cases          975.0
# new_deaths           8.0
# new_tests            NaN
# Name: 246, dtype: object

# %% [markdown]
# printing the data for the rage of values

# %%
covid_df.loc[108:113]
# Out:
#            date  new_cases  new_deaths  new_tests
# 108  2020-04-17     3786.0       525.0        NaN
# 109  2020-04-18     3493.0       575.0        NaN
# 110  2020-04-19     3491.0       480.0        NaN
# 111  2020-04-20     3047.0       433.0     7841.0
# 112  2020-04-21     2256.0       454.0    28095.0
# 113  2020-04-22     2729.0       534.0    44248.0

# %% [markdown]
# to copy the heet with name of df foe easy working

# %%
df=covid_df.copy()

# %% [markdown]
# to find sum f a specific column

# %%
df.new_cases.sum()
# Out:
# 271515.0

# %% [markdown]
# to find sum f a specific column

# %%
df.new_deaths.sum()
# Out:
# 35497.0

# %% [markdown]
# to store the sum in a

# %%
a=df.new_cases.sum()

# %% [markdown]
# to store the sum in b

# %%
b=df.new_deaths.sum()

# %% [markdown]
# to store the ratio of a and b in c

# %%
c=b/a

# %% [markdown]
# to  pringusing the format

# %%
print('the nmbers of repeated cases is {} and the number of repeated deaths is{}'.format(int(a),int(b)))
# Out:
# the nmbers of repeated cases is 271515 and the number of repeated deaths is35497

# %% [markdown]
# to print using the format

# %%
print("the overall repeated death case{:.2f}%".format(c*100))
# Out:
# the overall repeated death case13.07%

# %% [markdown]
# what is overall test conducted if a total of 935310 test were conducted before daily test reports were conducted

# %%
initial_tests=935310

# %%
df.new_tests.sum()+initial_tests
# Out:
# 5214766.0
